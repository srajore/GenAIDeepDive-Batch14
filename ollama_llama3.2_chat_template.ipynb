# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_template(
        #input_variables=["person"], 
        "Tell me the key achivements of {person} in four bulleted points, if you don't have information please say I don't know ,please help me with correct responses only"
    )

# %%
prompt = prompt = ChatPromptTemplate([
    ("system", "You are a helpful assistant. Please respond to the user as helpfully and accurately as possible."),
    ("user", "Tell me the key achievements of {person} in four bulleted points. If you don't have information, please say I don't know.")
])

# %%
llm = ChatOllama(model="llama3.2:latest")

# %%
chain = prompt | llm

# %%
response = chain.invoke({"person": "Narendra Modi"})

# %%
print(response.content)
# Out:
# Here are four key achievements of Narendra Modi:
#
# * **Digital India Initiative**: Modi launched the Digital India initiative in 2015, aiming to promote digital literacy and transform India's economy through technology. The initiative has led to significant investments in digital infrastructure, including high-speed internet connectivity.
# * **Make in India**: In 2014, Modi launched the Make in India initiative, a flagship program aimed at promoting manufacturing in India. The initiative has attracted significant foreign investment and has helped increase India's exports.
# * **Swachh Bharat Abhiyan (Clean India Mission)**: Modi initiated the Swachh Bharat Abhiyan in 2014, a massive sanitation campaign aimed at improving waste management and hygiene across India. The mission has led to a significant reduction in open defecation and improved public health.
# * **Economic Growth**: During Modi's tenure as Prime Minister, India has experienced rapid economic growth, with GDP growth averaging around 7% per annum. The government has also implemented various policies aimed at promoting economic development and reducing poverty.
#
# I hope this information is helpful!
